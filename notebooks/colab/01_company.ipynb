# %%
# %pip install -q dartlab

# %%
import dartlab

c = dartlab.Company("005930")
c.corpName

# %%
# 사용 가능한 topic 목록
c.topics

# %%
# 손익계산서 (분기)
c.show("IS")

# %%
# 연간 합산
c.show("IS", freq="Y")

# %%
# 행 필터
c.select("IS")

# %%
# 주석 — 재고자산
c.show("inventory")

# %%
# 정형 공시 — 배당
c.show("dividend")

# %%
c.sections.head(20)

# %%
c.trace("BS")

# %%
c.filings().head(10)

# %%
c.diff()
