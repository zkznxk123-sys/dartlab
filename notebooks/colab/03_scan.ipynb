# %%
# %pip install -q dartlab

# %%
import dartlab
# 가이드 — 13축
dartlab.scan()

# %%
# 수익성 횡단
dartlab.scan("profitability")

# %%
# 지배구조
dartlab.scan("governance")

# %%
# 부채/리스크
dartlab.scan("debt")
