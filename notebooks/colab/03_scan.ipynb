# %% [markdown]
# # 03 — scan: 전종목 횡단
#
# `dartlab.scan(axis, key)` 로 모든 상장사를 같은 계정·같은 지표로 비교한다.

# %%
# %pip install -q dartlab

# %%
import dartlab

# 가이드 — 13축
dartlab.scan()

# %% [markdown]
# ## 계정 횡단 — 특정 계정(매출액)을 전종목에서 뽑기

# %%
dartlab.scan("account", "매출액")
