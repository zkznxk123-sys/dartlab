# %% [markdown]
# # Scan
#
# 전 종목 횡단 분석 — 시장 전체를 한 번에. 13축.

# %%
# %pip install -q dartlab

# %%
import dartlab
dartlab.scan()

# %% [markdown]
# ## 수익성 횡단

# %%
dartlab.scan("profitability")

# %% [markdown]
# ## 지배구조

# %%
dartlab.scan("governance")

# %% [markdown]
# ## 부채/리스크

# %%
dartlab.scan("debt")
