# %% [markdown]
# # Quant
#
# 주가 기술적 분석 — 25지표 + 9신호.

# %%
# %pip install -q dartlab

# %%
import dartlab
c = dartlab.Company("005930")
c.quant()

# %% [markdown]
# ## 종합 판단

# %%
c.quant("종합")

# %% [markdown]
# ## 모멘텀 / RSI

# %%
c.quant("모멘텀")
