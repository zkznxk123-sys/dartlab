# %%
# %pip install -q dartlab

# %%
import dartlab

c = dartlab.Company("005930")
# 가이드 — 14축 + forecast + valuation
c.analysis()

# %%
# 수익성
c.analysis("수익성")

# %%
# 성장성
c.analysis("성장성")

# %%
# 안정성
c.analysis("안정성")

# %%
# 현금흐름
c.analysis("현금흐름")

# %%
# 매출전망
c.analysis("매출전망")

# %%
# 가치평가
c.analysis("가치평가")
