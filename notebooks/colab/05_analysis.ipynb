# %% [markdown]
# # Analysis
#
# 14축 재무 분석 + forecast + valuation. 6막 인과 구조.

# %%
# %pip install -q dartlab

# %%
import dartlab
c = dartlab.Company("005930")
c.analysis()

# %% [markdown]
# ## financial 그룹

# %%
c.analysis("수익성")

# %%
c.analysis("성장성")

# %%
c.analysis("안정성")

# %%
c.analysis("현금흐름")

# %% [markdown]
# ## forecast / valuation

# %%
c.analysis("매출전망")

# %%
c.analysis("가치평가")
