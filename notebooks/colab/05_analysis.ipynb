# %%
# %pip install -q dartlab

# %%
# dartlab 임포트
import dartlab

# %%
# 종목코드로 Company 생성
c = dartlab.Company("005930")

# %%
# analysis 가이드 — 14축 목록 확인
c.analysis()

# %%
# 수익성 분석
c.analysis("financial", "수익성")
