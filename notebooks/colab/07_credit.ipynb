# %% [markdown]
# # Credit
#
# 독립 신용평가 엔진 — 7축 dCR 등급.

# %%
# %pip install -q dartlab

# %%
import dartlab
c = dartlab.Company("005930")
c.credit()

# %%
c.credit("등급")

# %%
c.credit("수익성")

# %%
c.credit("부채")
