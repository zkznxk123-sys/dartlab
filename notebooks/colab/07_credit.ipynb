# %% [markdown]
# # 07 — credit: dCR 7축 등급
#
# `c.credit(axis)` 는 dartlab 내부 신용평가 모델(dCR) 출력을 축별로 보여준다.

# %%
# %pip install -q dartlab

# %%
import dartlab

c = dartlab.Company("005930")
# 가이드 — 7축 dCR 등급
c.credit()

# %% [markdown]
# ## 종합등급 · 수익성 · 부채

# %%
# 등급
c.credit("등급")

# %%
# 수익성
c.credit("수익성")

# %%
# 부채
c.credit("부채")
