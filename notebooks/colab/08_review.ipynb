# %% [markdown]
# # 08 — review: 구조화 보고서
#
# `c.review(section)` 은 숫자를 서술형 보고서로 조립한다. `toMarkdown()` 으로 문자열 출력.

# %%
# %pip install -q dartlab

# %%
import dartlab

c = dartlab.Company("005930")

# %% [markdown]
# ## 섹션 단위 호출 — 메모리 안전

# %%
# 단일 섹션 (메모리 안전 — 추천)
print(c.review("수익성").toMarkdown())

# %%
print(c.review("성장성").toMarkdown())

# %% [markdown]
# ## AI 종합의견 (reviewer) — provider 키 필요

# %%
# AI 종합의견 포함
# c.reviewer(guide="반도체 사이클 관점에서 평가해줘")
