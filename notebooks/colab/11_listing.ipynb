# %% [markdown]
# # Listing
#
# 상장 종목 / 공시 메타데이터 카탈로그.

# %%
# %pip install -q dartlab

# %%
import dartlab
dartlab.listing()

# %%
dartlab.listing("all")

# %%
dartlab.listing("filings", corp="005930")
